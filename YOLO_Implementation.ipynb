# %%
! pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 109.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.5/112.6 GB disk)

# %%
from importlib.metadata import version
# import package and authentication roboflow
from roboflow import Roboflow

rf=Roboflow(api_key="4sGvq8dK2YQqFiADuN0Z") # replace with the roboflow api

#set workspace projects and version

Workspac="roboflow-58fyf"
project_name="rock-paper-scissors-sxsw"
version_number=14
Project=rf.workspace(Workspac).project(project_name)
version=Project.version(version_number)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset=version.download("yolov11")
# Out:
# ...
# Extracting Dataset Version Zip to rock-paper-scissors-14 in yolov11:: 100%|██████████| 14682/14682 [00:02<00:00, 7181.38it/s]

# %%
# path to data set .yaml

dataset_yaml_path="/content/rock-paper-scissors-14/data.yaml"
print("datasets ready at: ",dataset_yaml_path)
# Out:
# datasets ready at:  /content/rock-paper-scissors-14/data.yaml

# %%
from ultralytics import YOLO
model=YOLO("yolov11n.pt")
result=model.train(data=dataset_yaml_path,epochs=1,imgsz=640,batch=16)
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# validate you model

val_result=model.val(data=dataset_yaml_path)
print("validation complementation")
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 897.2±281.9 MB/s, size: 29.5 KB)
# val: Scanning /content/rock-paper-scissors-14/valid/labels.cache... 576 images, 238 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 576/576 967.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 36/36 5.3it/s 6.8s
#                    all        576        400      0.536       0.42      0.437      0.229
#                  Paper        132        139      0.458      0.194      0.176     0.0745
#                   Rock        121        141       0.85      0.461      0.674      0.413
#               Scissors        116        120      0.301      0.606      0.462      0.198
# Speed: 0.7ms preprocess, 4.8ms inference, 0.0ms loss, 1.9ms postprocess per image
# ...
